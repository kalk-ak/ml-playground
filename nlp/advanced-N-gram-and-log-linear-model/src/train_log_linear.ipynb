# %%
from google.colab import drive
from google.colab import files

# This will trigger an authentication prompt in VS Code
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd

# %cd /content/
# Out:
# /content
# /content

# %%
# !ls drive/MyDrive/data_for_ml/
# Out:
# data.zip

# %%
# !ls /content/src/

# !rm /content/src/ -r
# Out:
# ls: cannot access '/content/src/': No such file or directory

# %%
# Run to download data again from drive

# !rm /content/src/data/downloaded.txt
# Out:
# rm: cannot remove '/content/src/data/downloaded.txt': No such file or directory

# %%
import os
from getpass import getpass

CODE_DIR = '/content/src/'
DATA_DIR = '/content/src/data/'
DRIVE_ARCHIVE = '/content/drive/MyDrive/data_for_ml/data.zip'


# github username
USER = 'kalk-ak'

REPO_NAME = "n-gram-and-log-linear-model"
# Get PAT
print("Enter your GitHub PAT:")
token = getpass()

if not os.path.exists(CODE_DIR + "downloaded.txt"):
    # Clone my private repo
    # !git clone https://{USER}:{token}@github.com/{USER}/{REPO_NAME}.git {CODE_DIR}

    print("Downloaded from Repo Sucessfully  ")
    with open(CODE_DIR + "downloaded.txt", "w") as f:
        f.write("Downloaded")

# 2. SETUP DATA
if not os.path.exists(DATA_DIR + "downloaded.txt"):
    print("Creating data directory...")
    os.makedirs(DATA_DIR, exist_ok=True)

    print(f"Extracting data to {DATA_DIR}...")
    # -d tells unzip exactly where to put the files
    # !unzip -q {DRIVE_ARCHIVE} -d {DATA_DIR}

    with open(DATA_DIR + "downloaded.txt", "w") as f:
        f.write("Downloaded")

print("Directory Structure Ready.")
# Out:
# Enter your GitHub PAT:
# ··········
# Cloning into '/content/src'...
# remote: Enumerating objects: 227, done.
# remote: Counting objects: 100% (227/227), done.
# remote: Compressing objects: 100% (118/118), done.
# remote: Total 227 (delta 131), reused 202 (delta 106), pack-reused 0 (from 0)
# Receiving objects: 100% (227/227), 3.20 MiB | 10.56 MiB/s, done.
# Resolving deltas: 100% (131/131), done.
# Filtering content: 100% (4/4), 12.36 MiB | 7.37 MiB/s, done.
# Downloaded from Repo Sucessfully
# Creating data directory...
# Extracting data to /content/src/data/...
# Directory Structure Ready.

# %%
# !ls
# !ls src/
# !ls src/data/data/
# Out:
# drive  sample_data  src
# code  data  downloaded.txt
# english_spanish  gen_spam  speech

# %% [markdown]
# ### Switch to working repo code

# %%
cd src/
# Out:
# /content/src

# %% [markdown]
# ### Train the Log Linear model on Colab GPU

# %%
# Cell for updating code repo
# %cd /content/src/code/

# !git pull

# %cd ../
# Out:
# /content/src/code
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 514 bytes | 257.00 KiB/s, done.
# From https://github.com/kalk-ak/n-gram-and-log-linear-model
#    5e595b3..ff8ff26  master     -> origin/master
# Updating 5e595b3..ff8ff26
# Fast-forward
#  code/probs.py | 10 +++++++---
#  1 file changed, 7 insertions(+), 3 deletions(-)
# /content/src

# %%
# !pip install -r code/requirements.txt
# Out:
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from -r code/requirements.txt (line 2)) (6.17.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r code/requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r code/requirements.txt (line 4)) (2.9.0+cu126)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from -r code/requirements.txt (line 5)) (1.16.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r code/requirements.txt (line 6)) (4.67.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from -r code/requirements.txt (line 9)) (10.8.0)
# Requirement already satisfied: jaxtyping in /usr/local/lib/python3.12/dist-packages (from -r code/requirements.txt (line 10)) (0.3.6)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.12/dist-packages (from -r code/requirements.txt (line 11)) (1.7.4.5)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from -r code/requirements.txt (line 12)) (13.9.4)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from -r code/requirements.txt (line 13)) (1.2.1)
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (from -r code/requirements.txt (line 14)) (2.15.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (from -r code/requirements.txt (line 15)) (0.12.0)
# Requirement already satisfied: rank_bm25 in /usr/local/lib/python3.12/dist-packages (from -r code/requirements.txt (line 16)) (0.2.2)
# Requirement already satisfied: beartype in /usr/local/lib/python3.12/dist-packages (from -r code/requirements.txt (line 17)) (0.22.9)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.12/dist-packages (from -r code/requirements.txt (line 18)) (4.4.4)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r code/requirements.txt (line 2)) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r code/requirements.txt (line 2)) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r code/requirements.txt (line 2)) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r code/requirements.txt (line 2)) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r code/requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r code/requirements.txt (line 2)) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r code/requirements.txt (line 2)) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r code/requirements.txt (line 2)) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r code/requirements.txt (line 2)) (6.5.1)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r code/requirements.txt (line 2)) (5.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r code/requirements.txt (line 4)) (3.5.0)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from jaxtyping->-r code/requirements.txt (line 10)) (0.1.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle->-r code/requirements.txt (line 11)) (6.3.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.12/dist-packages (from kaggle->-r code/requirements.txt (line 11)) (2026.1.4)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from kaggle->-r code/requirements.txt (line 11)) (3.4.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from kaggle->-r code/requirements.txt (line 11)) (3.11)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle->-r code/requirements.txt (line 11)) (5.29.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kaggle->-r code/requirements.txt (line 11)) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle->-r code/requirements.txt (line 11)) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle->-r code/requirements.txt (line 11)) (2.32.4)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.12/dist-packages (from kaggle->-r code/requirements.txt (line 11)) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.12/dist-packages (from kaggle->-r code/requirements.txt (line 11)) (1.3)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle->-r code/requirements.txt (line 11)) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from kaggle->-r code/requirements.txt (line 11)) (0.5.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->-r code/requirements.txt (line 12)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->-r code/requirements.txt (line 12)) (2.19.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai->-r code/requirements.txt (line 14)) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai->-r code/requirements.txt (line 14)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai->-r code/requirements.txt (line 14)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai->-r code/requirements.txt (line 14)) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai->-r code/requirements.txt (line 14)) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai->-r code/requirements.txt (line 14)) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken->-r code/requirements.txt (line 15)) (2025.11.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai->-r code/requirements.txt (line 14)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai->-r code/requirements.txt (line 14)) (0.16.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->-r code/requirements.txt (line 2)) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->-r code/requirements.txt (line 2)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->-r code/requirements.txt (line 2)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->-r code/requirements.txt (line 2)) (3.0.52)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->-r code/requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->-r code/requirements.txt (line 2)) (4.9.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->-r code/requirements.txt (line 2)) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->-r code/requirements.txt (line 2)) (5.9.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->-r code/requirements.txt (line 12)) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai->-r code/requirements.txt (line 14)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai->-r code/requirements.txt (line 14)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai->-r code/requirements.txt (line 14)) (0.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r code/requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r code/requirements.txt (line 4)) (3.0.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r code/requirements.txt (line 2)) (0.8.5)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->-r code/requirements.txt (line 2)) (4.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r code/requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->-r code/requirements.txt (line 2)) (0.2.14)

# %%
# !ls code/vocab
# Out:
# en_1k_vocab.txt        sp_1k_vocab.txt	      vocab-genspam.txt
# eng_spanish_10k.vocab  switchboard-small.txt
# kaggle.vocab	       switchboard.txt

# %%
# !ls code
# Out:
# build_vocab.py	  integerize.py    __pycache__	      textcat.py
# calendar-app	  models_trained   requirements.txt   train_lm.py
# combine_vocab.py  modern-showcase  SGD_convergent.py  train_log_linear.ipynb
# data		  my_file.txt	   split_data.py      trigram_randsent.py
# email.txt	  nlp-class.yml    test_accuracy.py   vocab
# fileprob.py	  probs.py	   test_backoff.py

# %%
# !mkdir /content/src/code/models_trained_colab

# %%
# !code/train_lm.py code/vocab/switchboard.txt log_linear_improved data/data/speech/train/switchboard --lexicon data/lexicons/words-gs-only-200.txt --epochs 20 --l2_regularization 0.5 --output code/models_trained_colab/log_linear_switchboard.model --device cuda
# Out:
# INFO:probs:Read vocab of size 11420 from code/vocab/switchboard.txt
# INFO:root:BOS is part of the vocab
# dimension = ['9849', '200']
# row = 9849
# col = 200
# INFO:root:Created a lexion matrix of shape torch.Size([4912, 200])
# INFO:train_lm:Training...
# INFO:root:Training on cuda...
# INFO:root:Set learning rate to 0.05
# INFO:root:Vectorizing training corpus...
# INFO:root:Start optimizing on 2192484 training tokens (20 epochs)...
# Epoch 1: 100% 536/536 [00:25<00:00, 21.04it/s]
# INFO:root:Epoch 1: F = -5.973392781534466
# Epoch 2: 100% 536/536 [00:24<00:00, 22.07it/s]
# INFO:root:Epoch 2: F = -5.837085587964866
# Epoch 3: 100% 536/536 [00:24<00:00, 22.05it/s]
# INFO:root:Epoch 3: F = -5.824912626281404
# Epoch 4: 100% 536/536 [00:24<00:00, 21.96it/s]
# INFO:root:Epoch 4: F = -5.819956416129371
# Epoch 5: 100% 536/536 [00:24<00:00, 21.97it/s]
# INFO:root:Epoch 5: F = -5.817421489868207
# Epoch 6: 100% 536/536 [00:24<00:00, 21.98it/s]
# INFO:root:Epoch 6: F = -5.815959599495781
# Epoch 7: 100% 536/536 [00:24<00:00, 22.08it/s]
# INFO:root:Epoch 7: F = -5.815050139412718
# Epoch 8: 100% 536/536 [00:24<00:00, 21.97it/s]
# INFO:root:Epoch 8: F = -5.814453663543491
# Epoch 9: 100% 536/536 [00:24<00:00, 22.00it/s]
# INFO:root:Epoch 9: F = -5.814046963997605
# Epoch 10: 100% 536/536 [00:24<00:00, 21.99it/s]
# INFO:root:Epoch 10: F = -5.813760956545361
# Epoch 11: 100% 536/536 [00:24<00:00, 21.95it/s]
# INFO:root:Epoch 11: F = -5.813555093666317
# Epoch 12: 100% 536/536 [00:24<00:00, 21.92it/s]
# INFO:root:Epoch 12: F = -5.813403847100026
# Epoch 13: 100% 536/536 [00:24<00:00, 21.94it/s]
# INFO:root:Epoch 13: F = -5.813290959232767
# Epoch 14: 100% 536/536 [00:24<00:00, 21.99it/s]
# INFO:root:Epoch 14: F = -5.813205467475439
# Epoch 15: 100% 536/536 [00:24<00:00, 21.99it/s]
# INFO:root:Epoch 15: F = -5.813139857719113
# Epoch 16: 100% 536/536 [00:24<00:00, 22.04it/s]
# INFO:root:Epoch 16: F = -5.81308904265944
# Epoch 17: 100% 536/536 [00:24<00:00, 22.02it/s]
# INFO:root:Epoch 17: F = -5.813049361206869
# Epoch 18: 100% 536/536 [00:24<00:00, 22.08it/s]
# INFO:root:Epoch 18: F = -5.813017938715053
# Epoch 19: 100% 536/536 [00:24<00:00, 22.03it/s]
# INFO:root:Epoch 19: F = -5.8129930371630465
# Epoch 20: 100% 536/536 [00:24<00:00, 22.07it/s]
# INFO:root:Epoch 20: F = -5.812973026249564
# INFO:probs:Saving model to code/models_trained/log_linear_switchboard.model
# INFO:probs:Saved model to code/models_trained/log_linear_switchboard.model

# %% [markdown]
# ### Download the trained model to do further analysis on my local machine

# %%
files.download("/content/src/code/models_trained_colab/log_linear_switchboard.model")
